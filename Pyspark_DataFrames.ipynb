# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmahmoodiagents/BigData/blob/main/Pyspark_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sample_data/california_housing_train.csv

# %%
# !pip install pyspark --q

# %%
from pyspark.sql import SparkSession, Row

# %%
sp = SparkSession.builder.appName("First").getOrCreate()

# %%
rd = sp.sparkContext.parallelize([Row("Alice", 34), Row("Bob", 45), Row("Cathy", 29)])

# %%
rd.collect()
# Out:
# [<Row('Alice', 34)>, <Row('Bob', 45)>, <Row('Cathy', 29)>]

# %%
# dff = rd.toDF()
dff1 =  rd.toDF(["name", "age"])

# %%
dff1.show()
# Out:
# +-----+---+
# | name|age|
# +-----+---+
# |Alice| 34|
# |  Bob| 45|
# |Cathy| 29|
# +-----+---+

# %%
newrd = dff1.rdd

# %%
newrd.collect()
# Out:
# [Row(name='Alice', age=34), Row(name='Bob', age=45), Row(name='Cathy', age=29)]

# %%
dff1.show()
# Out:
# +-----+---+
# | name|age|
# +-----+---+
# |Alice| 34|
# |  Bob| 45|
# |Cathy| 29|
# +-----+---+

# %%
dff.show()
# Out:
# +-----+---+
# |   _1| _2|
# +-----+---+
# |Alice| 34|
# |  Bob| 45|
# |Cathy| 29|
# +-----+---+

# %%
dff1.show()
# Out:
# +-----+---+
# | name|age|
# +-----+---+
# |Alice| 34|
# |  Bob| 45|
# |Cathy| 29|
# +-----+---+

# %% [markdown]
# # Extrating the data from csv file

# %%
df = sp.read.csv("sample_data/california_housing_train.csv", header=True)

# %%
df.show()
# Out:
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |  longitude| latitude|housing_median_age|total_rooms|total_bedrooms| population| households|median_income|median_house_value|
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |-114.310000|34.190000|         15.000000|5612.000000|   1283.000000|1015.000000| 472.000000|     1.493600|      66900.000000|
# |-114.470000|34.400000|         19.000000|7650.000000|   1901.000000|1129.000000| 463.000000|     1.820000|      80100.000000|
# |-114.560000|33.690000|         17.000000| 720.000000|    174.000000| 333.000000| 117.000000|     1.650900|      85700.000000|
# |-114.570000|33.640000|         14.000000|1501.000000|    337.000000| 515.000000| 226.000000|     3.191700|      73400.000000|
# ...

# %%
# import pandas as pd

# %%
# pd.read_csv("sample_data/california_housing_train.csv").describe()

# %%
df.describe().show()
# Out:
# +-------+-------------------+------------------+------------------+-----------------+-----------------+------------------+-----------------+------------------+------------------+
# |summary|          longitude|          latitude|housing_median_age|      total_rooms|   total_bedrooms|        population|       households|     median_income|median_house_value|
# +-------+-------------------+------------------+------------------+-----------------+-----------------+------------------+-----------------+------------------+------------------+
# |  count|              17000|             17000|             17000|            17000|            17000|             17000|            17000|             17000|             17000|
# |   mean|-119.56210823529375|  35.6252247058827| 28.58935294117647|2643.664411764706|539.4108235294118|1429.5739411764705|501.2219411764706| 3.883578100000021|207300.91235294117|
# ...

# %%
# df.rdd.collect()

# %%
df.rdd.getNumPartitions()
# Out:
# 1

# %%
df_repart = df.repartition(4)

# %%
df_repart.rdd.getNumPartitions()
# Out:
# 4

# %%
df_coalesce = df_repart.coalesce(2)

# %%
df_coalesce.rdd.getNumPartitions()
# Out:
# 2

# %%
smalldf = df.select("latitude","longitude","housing_median_age")

# %%
smalldf.show()
# Out:
# +---------+-----------+------------------+
# | latitude|  longitude|housing_median_age|
# +---------+-----------+------------------+
# |34.190000|-114.310000|         15.000000|
# |34.400000|-114.470000|         19.000000|
# |33.690000|-114.560000|         17.000000|
# |33.640000|-114.570000|         14.000000|
# |33.570000|-114.570000|         20.000000|
# |33.630000|-114.580000|         29.000000|
# |33.610000|-114.580000|         25.000000|
# |34.830000|-114.590000|         41.000000|
# |33.610000|-114.590000|         34.000000|
# |34.830000|-114.600000|         46.000000|
# |33.620000|-114.600000|         16.000000|
# |33.600000|-114.600000|         21.000000|
# |34.840000|-114.610000|         48.000000|
# |34.830000|-114.610000|         31.000000|
# |32.760000|-114.630000|         15.000000|
# |34.890000|-114.650000|         17.000000|
# |33.600000|-114.650000|         28.000000|
# |32.790000|-114.650000|         21.000000|
# |32.740000|-114.660000|         17.000000|
# ...

# %%
from pyspark.sql.functions import col

# %%
df.select(col("latitude"), col("longitude"), col("housing_median_age")).show()
# Out:
# +---------+-----------+------------------+
# | latitude|  longitude|housing_median_age|
# +---------+-----------+------------------+
# |34.190000|-114.310000|         15.000000|
# |34.400000|-114.470000|         19.000000|
# |33.690000|-114.560000|         17.000000|
# |33.640000|-114.570000|         14.000000|
# |33.570000|-114.570000|         20.000000|
# |33.630000|-114.580000|         29.000000|
# |33.610000|-114.580000|         25.000000|
# |34.830000|-114.590000|         41.000000|
# |33.610000|-114.590000|         34.000000|
# |34.830000|-114.600000|         46.000000|
# |33.620000|-114.600000|         16.000000|
# |33.600000|-114.600000|         21.000000|
# |34.840000|-114.610000|         48.000000|
# |34.830000|-114.610000|         31.000000|
# |32.760000|-114.630000|         15.000000|
# |34.890000|-114.650000|         17.000000|
# |33.600000|-114.650000|         28.000000|
# |32.790000|-114.650000|         21.000000|
# |32.740000|-114.660000|         17.000000|
# ...

# %%
df.show()
# Out:
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |  longitude| latitude|housing_median_age|total_rooms|total_bedrooms| population| households|median_income|median_house_value|
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |-114.310000|34.190000|         15.000000|5612.000000|   1283.000000|1015.000000| 472.000000|     1.493600|      66900.000000|
# |-114.470000|34.400000|         19.000000|7650.000000|   1901.000000|1129.000000| 463.000000|     1.820000|      80100.000000|
# |-114.560000|33.690000|         17.000000| 720.000000|    174.000000| 333.000000| 117.000000|     1.650900|      85700.000000|
# |-114.570000|33.640000|         14.000000|1501.000000|    337.000000| 515.000000| 226.000000|     3.191700|      73400.000000|
# ...

# %%
dfplus = df.withColumn("total_bedrooms_plus10", col("total_bedrooms") + 10)

# %%
dfplus.show()
# Out:
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+---------------------+
# |  longitude| latitude|housing_median_age|total_rooms|total_bedrooms| population| households|median_income|median_house_value|total_bedrooms_plus10|
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+---------------------+
# |-114.310000|34.190000|         15.000000|5612.000000|   1283.000000|1015.000000| 472.000000|     1.493600|      66900.000000|               1293.0|
# |-114.470000|34.400000|         19.000000|7650.000000|   1901.000000|1129.000000| 463.000000|     1.820000|      80100.000000|               1911.0|
# |-114.560000|33.690000|         17.000000| 720.000000|    174.000000| 333.000000| 117.000000|     1.650900|      85700.000000|                184.0|
# ...

# %%
dfdrop = dfplus.drop("total_bedrooms_plus10")

# %%
dfdrop.show()
# Out:
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |  longitude| latitude|housing_median_age|total_rooms|total_bedrooms| population| households|median_income|median_house_value|
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |-114.310000|34.190000|         15.000000|5612.000000|   1283.000000|1015.000000| 472.000000|     1.493600|      66900.000000|
# |-114.470000|34.400000|         19.000000|7650.000000|   1901.000000|1129.000000| 463.000000|     1.820000|      80100.000000|
# |-114.560000|33.690000|         17.000000| 720.000000|    174.000000| 333.000000| 117.000000|     1.650900|      85700.000000|
# |-114.570000|33.640000|         14.000000|1501.000000|    337.000000| 515.000000| 226.000000|     3.191700|      73400.000000|
# ...

# %%
df.show()
# Out:
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |  longitude| latitude|housing_median_age|total_rooms|total_bedrooms| population| households|median_income|median_house_value|
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |-114.310000|34.190000|         15.000000|5612.000000|   1283.000000|1015.000000| 472.000000|     1.493600|      66900.000000|
# |-114.470000|34.400000|         19.000000|7650.000000|   1901.000000|1129.000000| 463.000000|     1.820000|      80100.000000|
# |-114.560000|33.690000|         17.000000| 720.000000|    174.000000| 333.000000| 117.000000|     1.650900|      85700.000000|
# |-114.570000|33.640000|         14.000000|1501.000000|    337.000000| 515.000000| 226.000000|     3.191700|      73400.000000|
# ...

# %%
df.withColumnRenamed("latitude", "new_latitude").show()
# Out:
# +-----------+------------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |  longitude|new_latitude|housing_median_age|total_rooms|total_bedrooms| population| households|median_income|median_house_value|
# +-----------+------------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |-114.310000|   34.190000|         15.000000|5612.000000|   1283.000000|1015.000000| 472.000000|     1.493600|      66900.000000|
# |-114.470000|   34.400000|         19.000000|7650.000000|   1901.000000|1129.000000| 463.000000|     1.820000|      80100.000000|
# |-114.560000|   33.690000|         17.000000| 720.000000|    174.000000| 333.000000| 117.000000|     1.650900|      85700.000000|
# |-114.570000|   33.640000|         14.000000|1501.000000|    337.000000| 515.000000| 226.000000|     3.191700|      73400.000000|
# ...

# %%
df.show()
# Out:
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |  longitude| latitude|housing_median_age|total_rooms|total_bedrooms| population| households|median_income|median_house_value|
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |-114.310000|34.190000|         15.000000|5612.000000|   1283.000000|1015.000000| 472.000000|     1.493600|      66900.000000|
# |-114.470000|34.400000|         19.000000|7650.000000|   1901.000000|1129.000000| 463.000000|     1.820000|      80100.000000|
# |-114.560000|33.690000|         17.000000| 720.000000|    174.000000| 333.000000| 117.000000|     1.650900|      85700.000000|
# |-114.570000|33.640000|         14.000000|1501.000000|    337.000000| 515.000000| 226.000000|     3.191700|      73400.000000|
# ...

# %% [markdown]
# #### Count

# %%
df.groupBy("total_rooms").count().show() # targets categorical data mainly
# Out:
# +-----------+-----+
# |total_rooms|count|
# +-----------+-----+
# |5228.000000|    1|
# |4190.000000|    2|
# |2502.000000|    5|
# |3174.000000|    2|
# |2706.000000|    4|
# | 966.000000|    7|
# |1915.000000|    4|
# |5774.000000|    1|
# | 873.000000|    4|
# |2612.000000|    6|
# |7836.000000|    1|
# |3855.000000|    2|
# |4159.000000|    2|
# |3357.000000|    1|
# |1064.000000|    4|
# |2390.000000|    4|
# |2608.000000|    7|
# | 474.000000|    2|
# |1656.000000|    5|
# |4222.000000|    1|
# +-----------+-----+
# only showing top 20 rows

# %% [markdown]
# #### Sorting

# %%
from pyspark.sql.functions import col

# %%
df.orderBy(col("housing_median_age").asc()).show(5)
# Out:
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |  longitude| latitude|housing_median_age|total_rooms|total_bedrooms| population| households|median_income|median_house_value|
# +-----------+---------+------------------+-----------+--------------+-----------+-----------+-------------+------------------+
# |-120.930000|37.650000|          1.000000|2254.000000|    328.000000| 402.000000| 112.000000|     4.250000|     189200.000000|
# |-122.000000|38.230000|          1.000000|2062.000000|    343.000000| 872.000000| 268.000000|     5.263600|     191300.000000|
# |-116.150000|33.640000|         10.000000|1711.000000|    499.000000|1896.000000| 443.000000|     1.655700|      65400.000000|
# |-116.320000|34.100000|         10.000000|4256.000000|    861.000000|1403.000000| 686.000000|     2.661800|      81000.000000|
# ...

# %%
df.describe().show()
# Out:
# +-------+-------------------+------------------+------------------+-----------------+-----------------+------------------+-----------------+------------------+------------------+
# |summary|          longitude|          latitude|housing_median_age|      total_rooms|   total_bedrooms|        population|       households|     median_income|median_house_value|
# +-------+-------------------+------------------+------------------+-----------------+-----------------+------------------+-----------------+------------------+------------------+
# |  count|              17000|             17000|             17000|            17000|            17000|             17000|            17000|             17000|             17000|
# |   mean|-119.56210823529375|  35.6252247058827| 28.58935294117647|2643.664411764706|539.4108235294118|1429.5739411764705|501.2219411764706| 3.883578100000021|207300.91235294117|
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- longitude: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- housing_median_age: string (nullable = true)
#  |-- total_rooms: string (nullable = true)
#  |-- total_bedrooms: string (nullable = true)
#  |-- population: string (nullable = true)
#  |-- households: string (nullable = true)
#  |-- median_income: string (nullable = true)
#  |-- median_house_value: string (nullable = true)

# %%
df1 = sp.createDataFrame([("Alice", "NY","NewSchool"), ("Bob", "DC","Old School"), ("Lisa", "MS", "St.Martin")], ["name", "state", "School"])
df2 = sp.createDataFrame([("David", "NY"), ("Veronica", "DC"), ("John", "NY")], ["First_name", "state"])

# %%
df1.show()
# Out:
# +-----+-----+----------+
# | name|state|    School|
# +-----+-----+----------+
# |Alice|   NY| NewSchool|
# |  Bob|   DC|Old School|
# | Lisa|   MS| St.Martin|
# +-----+-----+----------+

# %%
df2.show()
# Out:
# +----------+-----+
# |First_name|state|
# +----------+-----+
# |     David|   NY|
# |  Veronica|   DC|
# |      John|   NY|
# +----------+-----+

# %%
df1.join(df2, "state").show()
# Out:
# +-----+-----+----------+----------+
# |state| name|    School|First_name|
# +-----+-----+----------+----------+
# |   DC|  Bob|Old School|  Veronica|
# |   NY|Alice| NewSchool|     David|
# |   NY|Alice| NewSchool|      John|
# +-----+-----+----------+----------+

# %%
df.dropDuplicates([" "]).show()

# %%
df.select(" ").distinct().show()

# %%
df.na.fill({" ": 0}).show()

# %%
# df.createOrReplaceTempView("people")
# spark.sql("SELECT name FROM people WHERE age > 30").show()

# %%
# data = [("A", "Math", 90), ("A", "Eng", 80), ("B", "Math", 85)]
# df = spark.createDataFrame(data, ["student", "subject", "score"])
# df.groupBy("student").pivot("subject").avg("score").show()
